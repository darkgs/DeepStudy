# %%
params = {
    'batch_size': 32,
    'embed_size': 1024,
    'rnn_hidden_size': 1024,
    'rnn_num_layers': 1,
    'cap_max_len': 80,
}

# %%
from coco_dataset import CocoCap
coco_data = CocoCap(params)
coco_data.load()
# Out:
# loading annotations into memory...
# Done (t=0.59s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.04s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.57s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.15s)
# creating index...
# index created!
# Loads pre-trained model - success
# 2

# %%
import numpy as np

import matplotlib
import matplotlib.pyplot as plt

image_data, caption = coco_data.test()

image_data = np.transpose(image_data, (1, 2, 0))
plt.imshow(image_data)
print(caption)
# Out:
# A woman is sitting at a table with a cake
